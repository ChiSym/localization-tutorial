# %% [markdown]
# # Mapping tutorial

# %%
# Global setup code

import genstudio.plot as Plot
import itertools
import jax
import jax.numpy as jnp
import genjax
from urllib.request import urlopen
from genjax import SelectionBuilder as S
from genjax import ChoiceMapBuilder as C
from genjax import pretty
from genjax.typing import IntArray, FloatArray, PRNGKey
from penzai import pz
from typing import Any, Iterable

import os

pretty()

html = Plot.Hiccup
Plot.configure({"display_as": "html", "dev": False})

# Ensure a location for image generation.
os.makedirs("imgs", exist_ok=True)

# %% [markdown]
# ## Basic data structures

# %%
@pz.pytree_dataclass
class Blocks(genjax.PythonicPytree):
    pos: IntArray
    present: FloatArray

grid = r"""
.....................
.....................
.XXX..........X......
.X.X..........X......
.X............XXX....
.X..............X....
.X..............X....
.XX............XXX...
..X..............X...
..X..............X...
..X..............X...
..X..............X...
..XXXXX......XXXXX...
......X......X.......
......X....XXX.......
......X....X.........
......X....X.........
......XXXXXX.........
.....................
.....................
.....................
"""

GRID_RADIUS = 10

def all_grid_points(radius):
    return jnp.stack(jnp.meshgrid(jnp.arange(-radius, radius + 1), jnp.arange(-radius, radius + 1)), axis=-1).reshape(-1, 2)

ALL_GRID_POINTS = all_grid_points(GRID_RADIUS)

# extract the points from the grid string:
def extract_points_from_grid_string(grid_string):
    lines = grid_string.strip().split("\n")
    height = len(lines)
    width = len(lines[0])
    present = jnp.zeros((height, width))
    for i, line in enumerate(lines):
        for j, char in enumerate(line):
            if char == "X":
                present = present.at[i, j].set(1)
    return present.flatten()

true_presence = extract_points_from_grid_string(grid)

true_blocks = Blocks(ALL_GRID_POINTS, true_presence)

# %% [markdown]
# ## Plotting

# %%
OFFSETS = jnp.array([
    [-0.5, -0.5],
    [0.5, -0.5],
    [0.5, 0.5],
    [-0.5, 0.5],
])

OFFSETS_CLOSED = jnp.concat([OFFSETS, OFFSETS[:1]], axis=0)

def plot_blocks(blocks: Blocks):
    block_vertices = blocks.pos[:, None, :] + OFFSETS_CLOSED[None, :, :]
    return [Plot.line(vertices, fill="black", fillOpacity=present) for vertices, present in zip(block_vertices, blocks.present) if present > 0]

def line_segments_of_block(block: IntArray):
    vertices = block[None, :] + OFFSETS
    return jnp.stack([vertices, jnp.roll(vertices, 1, axis=0)], axis=1)

line_segments = jax.vmap(line_segments_of_block, in_axes=0)

def world_plot_spec(blocks):
    lines = plot_blocks(blocks)
    return lines + Plot.ellipse([[0, 0]], r=0.2, fill="red")

def plot_world(blocks):
    return wrap_plot(
        world_plot_spec(blocks)
    )

def wrap_plot(p):
    return Plot.new(
        p,
        {"width": 500, "aspectRatio": 1},
        Plot.domain([-10, 10], [-10, 10])
    )

# %%
plot_world(true_blocks)
# Out:
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-27e1a8e37a8f4619adfd49c608f63fe1"></div>
#
#     <script type="application/json">
b34ac1"}, {"__type__": "ref", "state_key": "7bdb7706-0066-457b-b039-f7be113f5611"}, {"__type__": "ref", "state_key": "7228388a-fa55-4425-a337-61198264630f"}, {"__type__": "ref", "state_key": "f7a6b957-69fc-4e54-9825-c8df8dc9a34d"}, {"__type__": "ref", "state_key": "377ea397-4760-41b4-ba2f-aee796266ef5"}, {"__type__": "ref", "state_key": "76c069cf-6130-4f0e-99dc-25ea30a41787"}, {"__type__": "ref", "state_key": "561fffc6-682c-48df-b586-d3b4e50e3a54"}, {"__type__": "ref", "state_key": "212f2f15-2568-4f41-9c49-0c950bfd46aa"}, {"__type__": "ref", "state_key": "8bd8020e-cd64-4ff4-8ba5-ccd2019d5cd0"}, {"__type__": "ref", "state_key": "69adecd2-cef2-471d-8d54-871637f3a374"}, {"__type__": "ref", "state_key": "590a1e3e-db25-4e32-b655-97213a19f0cc"}, {"__type__": "ref", "state_key": "0ddc3faf-d0d0-4e6b-a5e9-d338686c2243"}, {"__type__": "ref", "state_key": "3e5d5ce2-06f0-4f76-a219-bff2d350c6bf"}, {"__type__": "ref", "state_key": "c4c2e12f-91b5-47f2-98a5-3efd266225cc"}, {"__type__": "ref", "state_key": "a7d95af1-1bc4-445e-9b1e-9d82b72a3ca1"}, {"__type__": "ref", "state_key": "f2680d85-f24f-4aec-b616-93bc87aaece0"}, {"__type__": "ref", "state_key": "8fe9911c-83e7-4e7c-b267-c400aa52 ...

# %% [markdown]
# ## Prior

# %%
@genjax.gen
def block_prior_single(position: IntArray):
    present = genjax.bernoulli(0.0) @ "present"
    return Blocks(position, present)

blocks_prior = block_prior_single.vmap(in_axes=0)

# %%
key = jax.random.key(0)
sample_prior_jitted = jax.jit(blocks_prior.simulate)
tr = sample_prior_jitted(key, (ALL_GRID_POINTS,))
blocks = tr.get_retval()
log2_weight = tr.get_score() / jnp.log(2.0)
print(f"Log2(weight): {log2_weight}")
plot_world(blocks)
# Out:
# Log2(weight): -441.000244140625
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-8f7a09cc1206482097b6aedb9dc834da"></div>
#
#     <script type="application/json">
#         {"ast": {"__type__": "function", "path": "PlotSpec", "args": [{"layers": [{}, {"__type__": "ref", "state_key": "1d47ffb8-ba4d-4231-b437-3b6b28134e37"}, {"__type__": "ref", "state_key": "33df4a49-dd9b-4da5-9833-e362ec4914f4"}, {"__type__": "ref", "state_key": "d54dd29a-4cde-40e4-8b64-bce01656bc93"}, {"__type__": "ref", "state_key": "b4a3f8e2-1ad0-4be5-9580-c59d688b7da2"}, {"__type__": "ref", "state_key": "a8350d48-0a40-4ec3-b5fa-b9141855ceb9"}, {"__type__": "ref", "state_key": "e082fb4d-4ede-4f2e-940f-a858c4ec93f2"}, {"__type__": "ref", "state_key": "d383b4da-e0a2-4945-8c34-11fa8a339d62"}, {"__type__": "ref", "state_key": "03474186-b8fd-40cc-bd5b-44c8ce24a482"}, {"__type__": "ref", "state_key": "883a1d28-a852-4ad7-8366-5364c1552d97"}, {"__type__": "ref", "state_key": "cf6298b
857335a7-13be-4faf-a8e1-9b1e1102dc7d"}, {"__type__": "ref", "state_key": "b43706f3-3872-4c3e-9584-28fdb8ad4e07"}, {"__type__": "ref", "state_key": "8b9edaf7-1293-4fd7-9d49-bc0fd46bc86c"}, {"__type__": "ref", "state_key": "c5989eb0-e8a8-457d-b592-dff7dbfc3ac5"}, {"__type__": "ref", "state_key": "816288de-8864-45aa-8a56-27052d3d564d"}, {"__type__": "ref", "state_key": "98e5755d-bb79-40b2-b548-6360c2feac2d"}, {"__type__": "ref", "state_key": "8f9d4e75-8d01-49f8-8ff2-d44f943f822d"}, {"__type__": "ref", "state_key": "196344da-9f4d-4935-9053-5b06c2eef4a0"}, {"__type__": "ref", "state_key": "73f90daa-274d-4d22-a5e3-09292b00 ...

# %%
num_samples = 50
key, sub_key = jax.random.split(key)
repeated_grid_positions = jax.lax.broadcast(grid_positions, (num_samples,))
traces = jax.vmap(sample_prior_jitted, in_axes=0)(jax.random.split(sub_key, num_samples), (repeated_grid_positions,))
blocks = traces.get_retval()
average_blocks = Blocks(jnp.mean(blocks.pos, axis=0), jnp.mean(blocks.present, axis=0)) # TODO: why can't I apply this directly to Blocks? I thought Pytrees allowed this.
plot_world(average_blocks)
# Out:
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-73b6e965d8d94fb98758494280a00479"></div>
#
#     <script type="application/json">
#         {"ast": {"__type__": "function", "path": "PlotSpec", "args": [{"layers": [{}, {"__type__": "ref", "state_key": "4e6d6db4-757e-4335-8ff7-f5104cbcf242"}, {"__type__": "ref", "state_key": "f2b841a5-c111-49ba-a9aa-d01b567172df"}, {"__type__": "ref", "state_key": "f5e8ab13-60f5-4d69-8f86-c4133de13487"}, {"__type__": "ref", "state_key": "acb4a64d-cf98-4554-bd37-7111c8601c88"}, {"__type__": "ref", "state_key": "fa473d45-fc19-4e3d-96d6-abfc60a1386d"}, {"__type__": "ref", "state_key": "891a8bda-484f-4494-a307-226c85269873"}, {"__type__": "ref", "state_key": "74fe2a7c-89bc-4232-ad23-b996a8224f0a"}, {"__type__": "ref", "state_key": "1d196c10-feac-4868-8749-cd4e9a80081b"}, {"__type__": "ref", "state_key": "f7da94d0-93e9-4532-ba1e-52ae5f425c25"}, {"__type__": "ref", "state_key": "1ceb91f8-eb0a-49c7-909f-93127a0d97a0"}, {"__type__": "ref", "state_key": "80f04962-aaab-43b9-ad59-82e023cf8e37"}, {"__type__": "ref", "state_key": "f5fb76a0-9c20-4540-bb00-4e1828d4536b"}, {"__type__": "ref", "state_key": "5f66995d-9806-4a70-af7d-d5d5987807fe"}, {"__type__": "ref", "state_key": "a63dbd22-75ba-46eb-9b98-0ce2ce7ba70b"}, {"__type__": "ref", "state_key": "1c7278b8-24dd-41c2-836b-ea216cb853d1"}, {"__type__": "ref", "state_key": "c058f0fc-320c-4f71-b132-3009979f3549"}, {"__type__": "ref", "state_key": "e9503be4-6e36-4d85-8176-1cca0888971f"}, {"__type__": "ref", "state_key": "8c095b37-58b3-4ddc-8185-1ddd6a83022d"},
# %% [markdown]
# ## Exact sensor model

# %%
def solve_lines(p, u, q, v, PARALLEL_TOL=1.0e-10):
    """
    Solves for the intersection of two lines defined by points and direction vectors.

    Args:
    - p, u: Point and direction vector defining the first line.
    - q, v: Point and direction vector defining the second line.
    - PARALLEL_TOL: Tolerance for determining if lines are parallel.

    Returns:
    - s, t: Parameters for the line equations at the intersection point.
            Returns [-inf, -inf] if lines are parallel.
    """
    det = u[0] * v[1] - u[1] * v[0]
    return jnp.where(
        jnp.abs(det) < PARALLEL_TOL,
        jnp.array([-jnp.inf, -jnp.inf]),
        jnp.array(
            [
                (v[0] * (p[1] - q[1]) - v[1] * (p[0] - q[0])) / det,
                (u[1] * (q[0] - p[0]) - u[0] * (q[1] - p[1])) / det,
            ]
        ),
    )


def distance(dir, seg):
    """
    Computes the distance from the origin to a segment, in a given direction.

    Args:
    - p: The Pose object.
    - seg: The Segment object.

    Returns:
    - float: The distance to the segment. Returns infinity if no valid intersection is found.
    """
    pos = jnp.array([0, 0])
    a = solve_lines(pos, dir, seg[0], seg[1] - seg[0])
    return jnp.where(
        (a[0] >= 0.0) & (a[1] >= 0.0) & (a[1] <= 1.0),
        a[0],
        jnp.inf,
    )

def unit_dir(angle):
    return jnp.array([jnp.cos(angle), jnp.sin(angle)])

# %%
ANGLES = jnp.arange(0, 1, 0.04) * 2 * jnp.pi
MAX_DISTANCE = GRID_RADIUS * 2

def distance_to_block(dir, block):
    segs = line_segments_of_block(block.pos)
    dists = jax.vmap(lambda seg: distance(dir, seg))(segs)
    return jax.lax.cond(
        block.present > 0,
        lambda: jnp.min(dists, axis=0),
        lambda: jnp.inf)

def distance_to_blocks(dir, blocks):
    return jnp.minimum(jnp.min(jax.vmap(lambda block: distance_to_block(dir, block))(blocks), axis=0), MAX_DISTANCE)

def sensor_distances(blocks):
    return jax.vmap(lambda angle: distance_to_blocks(unit_dir(angle), blocks))(ANGLES)

def sensor_plot_spec(readings):
    unit_vecs = jax.vmap(unit_dir, in_axes=0)(ANGLES)
    ray_endpoints = unit_vecs * readings[:, None]
    return [
        Plot.line([[0, 0], [x, y]], stroke=Plot.constantly("sensor rays"))
        for x, y in ray_endpoints
    ] + [
        Plot.ellipse([endpoint], r=0.1, fill=Plot.constantly("sensor readings"))
        for endpoint in ray_endpoints
    ]


true_readings = sensor_distances(true_blocks)

def world_and_sensors_plot_spec(blocks, readings):
    return world_plot_spec(blocks) + sensor_plot_spec(readings)

wrap_plot(world_and_sensors_plot_spec(true_blocks, true_readings))
# Out:
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-f1c26c61a76248ddb71a89ace8914fe4"></div>
#
#     <script type="application/json">
51051cdeca9"}, {"__type__": "ref", "state_key": "5c541af4-5647-448a-bb8e-f8f56951ed87"}, {"__type__": "ref", "state_key": "08dad0de-b5b6-4d0f-90c9-5b1f20ca829d"}, {"__type__": "ref", "state_key": "05206ad8-49d4-4adc-a7c0-0d94b9779d6b"}, {"__type__": "ref", "state_key": "5cb356c0-595e-4f40-b6da-a139f7a8e2d4"}, {"__type__": "ref", "state_key": "66a2183f-f515-41df-b59e-4851868176b4"}, {"__type__": "ref", "state_key": "ac247d70-4dbc-4d22-b1f0-da62ae9929b7"}, {"__type__": "ref", "state_key": "05d6d9fa-fa71-4aa8-b13f-efe0f76bd67e"}, {"__type__": "ref", "state_key": "7b07e143-9689-450c-8748-15b2556c346d"}, {"__type__": "ref", "state_key": "4783fb3d-1427-4f14-b6cd-84c326323fec"}, {"__type__": "ref", "state_key": "0ed96bcc-42d2-40fb-8453-a2e8162a1d0a"}, {"__type__": "ref", "state_key": "637a575e-4133-41bf-bbd8-154d18bfdc23"}, {"__type__": "ref", "state_key": "c4ac50ad-b0f5-40ec-80ac-93b84536a7ca"}, {"__type__": "ref", "state_key": "c3f47433-16c3-47c8-a6e6-3c4ae5d6abb0"}, {"__type__": "ref", "state_key": "d5b2db96-2075-47a3-b5d5-3eaed11a ...

# %% [markdown]
# ## Noisy sensor model

# %%
NOISE = 0.5

@genjax.gen
def sensor_model_single(blocks, angle):
    return genjax.normal(distance_to_blocks(unit_dir(angle), blocks), NOISE) @ "readings"

sensor_model = sensor_model_single.vmap(in_axes=(None, 0))

# %%
key = jax.random.key(0)
trace = sensor_model.simulate(key, (true_blocks, ANGLES,))
readings = trace.get_retval()
wrap_plot(world_and_sensors_plot_spec(true_blocks, readings))
# Out:
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-f0db27a6cd71415fa8a846a32b8d4546"></div>
#
#     <script type="application/json">
#         {"ast": {"__type__": "function", "path": "PlotSpec", "args": [{"layers": [{}, {"__type__": "ref", "state_key": "e0ed9171-7fef-471f-a61f-9bf228e291ea"}, {"__type__": "ref", "state_key": "4af9db3d-1edd-4b1c-b08a-d42f2424918a"}, {"__type__": "ref", "state_key": "07011435-5d5f-4fb6-a2cc-b3ef2c7d4afe"}, {"__type__": "ref", "state_key": "6e5d9407-7330-4da4-87c4-adeeebbaced9"}, {"__type__": "ref", "state_key": "96cb3682-6c76-4702-a480-63aac962d61c"}, {"__type__": "ref", "state_key": "258fed8e-19ed-4569-b280-21642ed78246"}, {"__type__": "ref", "state_key": "8fceb701-1df5-43e8-94d8-3c07c857746d"}, {"__type__": "ref", "state_key": "b58fbf5d-1b27-44bb-85f8-4e03c1600b97"}, {"__type__": "ref", "state_key": "77fa52d6-666a-4672-9fe1-cf1a6538d78c"}, {"__type__": "ref", "state_key": "7437ba0c-f524-4efe-9a19-2d4dd1377617"}, {"__type__": "ref", "state_key": "0dbb8325-3c0b-4f3e-be86-d5e7190ac48f"}, {"__type__": "ref", "state_key": "5e6a287e-0953-4f17-89bc-96f1ab1a2799"}, {"__type__
6bb26265-cace-4dca-b9a9-295b5d37d87b"}, {"__type__": "ref", "state_key": "602fbfa1-e1f4-4727-a89a-ea24dcd12228"}, {"__type__": "ref", "state_key": "15abcb10-ca3d-4a1d-80b5-fc24dcbdb0df"}, {"__type__": "ref", "state_key": "c2706167-62f7-444c-bf94-fb658d17d0a5"}, {"__type__": "ref", "state_key": "902e8850-5e38-462a-b486-9bd08bbd13c0"}, {"__type__": "ref", "state_key": "bb6d8d94-42ad-4990-89cb-ff32c931 ...

# %% [markdown]
# ## Full model

# %%
@genjax.gen
def full_model():
    blocks = blocks_prior(ALL_GRID_POINTS) @ "blocks"
    readings = sensor_model(blocks, ANGLES) @ ()
    return (blocks, readings)

# %%
key = jax.random.key(1)
trace = full_model.simulate(key, ())
blocks, readings = trace.get_retval()
wrap_plot(world_and_sensors_plot_spec(blocks, readings))
trace.get_choices()
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_6c430400a9924164a1381fe4dc661957" ></treescope-container> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_6c430400a9924164a1381fe4dc661957")) .filter((elt) => !elt.dataset.setup) )[0]; root.dataset.setup = 1; const msg = document.createElement("span"); msg.style = "color: #cccccc; font-family: monospace;"; msg.textContent = "(Loading...)"; root.state.loadingMsg = msg; root.shadowRoot.appendChild(msg); root.state.chain = new Promise((resolve, reject) => { const observer = new IntersectionObserver((entries) => { for (const entry of entries) { if (entry.isIntersecting) { resolve(); observer.disconnect(); return; } } }, {rootMargin: "1000px"}); window.setTimeout(() => { observer.observe(root); }, 0); }); root.state.deferring = false; const _insertNode = (node) => { for (let oldScript of node.querySelectorAll("script")) { let newScript = document.createElement("script"); newScript.type = oldScript.type; newScript.textContent = oldScript.textContent; oldScript.parentNode.replaceChild(newScript, oldScript); } if (root.state.loadingMsg) { root.state.loadingMsg.remove(); root.state.loadingMsg = null; } root.shadowRoot.appendChild(node); }; root.defns.insertContent = ((contentNode, compressed) => { if (compressed) { root.state.deferring = true; } if (root.state.deferring) { root.state.chain = (async () => { await root.state.chain; if (compressed) { const encoded = contentNode.textContent; const blob = new Blob([ Uint8Array.from(atob(encoded), (m) => m.codePointAt(0)) ]); const reader = blob.stream().pipeThrough( new DecompressionStream("deflate") ).pipeThrough( new TextDecoderStream("utf-8") ).getReader(); const parts = []; while (true) { const step = await reader.read(); if (step.done) { break; } parts.push(step.value); } const tpl = document.createElement('template'); tpl.innerHTML = parts.join(""); _insertNode(tpl.content); } else { _insertNode(contentNode.content); } })(); } else { _insertNode(contentNode.content); } }); </script></treescope-run-here><div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_6c430400a9924164a1381fe4dc661957")) .filter((elt) => !elt.dataset['step0']) )[0]; root.dataset['step0'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# <div style="display:none"> <script type="application/octet-stream" >...</script> <treescope-run-here><script type="application/octet-stream"> const root = ( Array.from(document.getElementsByClassName( "treescope_out_6c430400a9924164a1381fe4dc661957")) .filter((elt) => !elt.dataset['step1']) )[0]; root.dataset['step1'] = 1; root.defns.insertContent( this.parentNode.querySelector('script[type="application/octet-stream"]'), true ); this.parentNode.remove(); </script></treescope-run-here> </div>
# Static({
#   'blocks': {
#     'present': Choice(
#       v=<jax.Array int32(441,) [≥0, ≤1] zero:202 nonzero:239>,
#     ),
#   },
#   'readings': Choice(
#     v=<jax.Array float32(25,) ≈1.4 ±0.98 [≥-0.38, ≤3.7] nonzero:25>,
#   ),
# })

# %%
key = jax.random.key(1)
trace = sensor_model.simulate(key, (true_blocks, ANGLES))
observed_readings = trace.get_retval()
wrap_plot(sensor_plot_spec(observed_readings))
# Out:
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-355786b6df074f9d8185ceca1d232b34"></div>
#
#     <script type="application/json">
#         {"ast": {"__type__": "function", "path": "PlotSpec", "args": [{"layers": [{}, {"__type__": "ref", "state_key": "a1b2998c-a395-44b0-a39e-c7d2bbcc4d70"}, {"__type__": "ref", "state_key": "ea7fca79-5662-479b-ab07-df8898646e94"}, {"__type__": "ref", "state_key": "a89cfca9-0a5e-42e6-8536-d8e2d216323b"}, {"__type__": "ref", "state_key": "b3e3e09b-3bdf-4be7-a8b0-f97e510ae288"}, {"__type__": "ref", "state_key": "592c2483-ec6d-45ac-864b-312a6eeb2388"}, {"__type__": "ref", "state_key": "4e54a816-a7e3-42a4-96ec-f91c1ad228dd"}, {"__type__": "ref", "state_key": "40ce60ef-7135-4591-8fd0-895f7fac9a46"}, {"__type__": "ref", "state_key": "bd19901c-89a8-431d-a730-27eaf5c62527"}, {"__type__": "ref", "state_key": "837cb996-e5c4-4c67-9262-ec3e197314a0"}, {"__type__": "ref", "state_key": "27fa9bd2-f315-4186-9ad2-f88d810c1c70"}, {"__type__": "ref", "state_key": "a5b91cf9-360e-4348-9d03-a09ae6dbc409"}, {"__type__": "ref", "state_key": "5433fcce-d9ba-4ab3-b1de-c21d31d7983e"}, {"__type__": "ref", "state_key": "270cc884-6cc3-4a90-a33a-31ec6ae7c0b2"}, {"__type__": "ref", "
# %% [markdown]
# ## Maximum a posteriori estimation

# %%
def map_estimation(key, observed_readings, N = 100):
    """Very naive MAP estimation. Just try N random samples and take the one with the highest weight."""
    model_importance = jax.jit(full_model.importance)
    keys = jax.random.split(key, N)
    constraints = C["readings"].set(observed_readings)
    traces, log_weights = jax.vmap(lambda key: model_importance(key, constraints, ()))(keys)
    log_weights = log_weights - jax.scipy.special.logsumexp(log_weights)
    print("Normalized log weights > -10: ", [lw.item() for lw in log_weights if lw > -10])
    best_index = jnp.argmax(log_weights)
    best_trace = jax.tree_util.tree_map(lambda trace: trace[best_index], traces)
    blocks, readings = best_trace.get_retval()
    return blocks

key, subkey = jax.random.split(key)
inferred_blocks = map_estimation(subkey, observed_readings, N=100000)
wrap_plot(world_and_sensors_plot_spec(inferred_blocks, observed_readings))
# Out:
# Log weights > -10:  [0.0]
#     <style>@import "https://cdn.jsdelivr.net/npm/@probcomp/genstudio@2025.1.12/dist/widget.css";</style>
#     <div class="bg-white p3" id="genstudio-widget-0fba244927094bfa841719275252cff2"></div>
#
#     <script type="application/json">
#         {"ast": {"__type__": "function", "path": "PlotSpec", "args": [{"layers": [{}, {"__type__": "ref", "state_key": "603a2563-4f1e-47d1-941e-359cdd036a21"}, {"__type__": "ref", "state_key": "b1902c7d-e87f-4ffc-9111-136d6a929380"}, {"__type__": "ref", "state_key": "2cc8edf7-bc26-4647-93a5-037764b26be9"}, {"__type__": "ref", "state_key": "0872356e-b7c3-4b16-9ab3-7f8ee96bca42"}, {"__type__": "ref", "state_key": "0baecab3-79f6-4621-82bb-e6d9b8841040"}, {"__type__": "ref", "state_key": "a172ae9d-dd97-4311-be56-3c7beba2c7f2"}, {"__type__": "ref", "state_key": "5a94feb3-5079-4ced-a9cc-95d5376ff135"}, {"__type__": "ref", "state_key": "0ea4c261-5708-4d07-8cc8-571916805df2"}, {"__type__": "ref", "state_key": "735f1635-66bb-4313-b099-dc9f7f497da1"}, {"__type__": "ref", "state_key": "95505c9a-cadc-4666-a4c9-e8613c788fe4"}, {"__type__": "ref", "state_key": "ce274748-53ec-49ab-972a-2cdf9e03f68d"}, {"__type__": "ref", "state_key": "948b6ec9-52e0-414e-ad03-22fe62354a1c"}, {"__type__": "ref", "state_key": "70193340-fafb-40db-abfa-b608bcf5cf07"}, {"__type__": "ref", "state_key": "5faac8fe-4b84-4bb4-b4c7-fc41b8010c2e"}, {"__type__": "ref", "state_key": "469ee53a-be43-48e0-8a27-7ad2d7d78a6b"}, {"__type__": "ref", "state_key": "f99e715d-db70-4c02-9945-184746d1b799"}, {"__type__": "ref", "state_key": "8fa9523e-309c-4dbf-8e8f-a1118355ec38"}, {"__type__": "ref", "state_key": "f16516ef-c9a5-48a2-b00b-8814c9d1225a"}, {"__type__": "ref", "state_